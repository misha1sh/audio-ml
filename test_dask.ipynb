# %%
from dask_kubernetes.operator import KubeCluster, make_cluster_spec

# spec = make_cluster_spec(name="mycluster")

# spec["spec"]["worker"]["spec"]["nodeSelector"] = {"worker": "true"}
# spec["spec"]["worker"]["spec"]["tolerations"] =[{
#         "key": "worker",
#         "value": "true",
#         "effect": "Schedule"
#     }]

# node_selector={"worker": "true"},
#     tolerations=[{
#         "key": "worker",
#         "value": "true",
#         "effect": "NoSchedule"
#     }]

# cluster = KubeCluster(custom_cluster_spec=spec)
cluster = KubeCluster(name="mycluster",
                      #image='daskdev/dask:latest',
                      image='cr.yandex/crp2897qtopgu6vmmabs/worker:latest',
                      worker_command="dask-worker --nthreads=1",
                      n_workers=2)
                    #   resources={"requests": {"memory": "2Gi"}, 
                    #              "limits": {"memory": "2Gi"}})
# cluster.adapt(minimum=1, maximum=1)
# cluster.scale(1)

print(cluster.dashboard_link)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# http://localhost:62798/status

# %%
from dask.distributed import Client

# %%
cluster.scale(3)

# %%
# kubectl port-forward --namespace default svc/mycluster-scheduler 8787:8787 &
# kubectl -n kubernetes-dashboard port-forward kubernetes-dashboard-758765f476-vhsgh 8443:8443 &
# kubectl -n kubernetes-dashboard create token admin-user
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().system('kubectl port-forward --namespace default svc/mycluster-scheduler 8787:8787 &')
#       2 # !kubectl -n kubernetes-dashboard port-forward kubernetes-dashboard-758765f476-vhsgh 8443:8443 &
#       3 #kubectl -n kubernetes-dashboard create token admin-user
#
# File ~/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py:633, in ZMQInteractiveShell.system_piped(self, cmd)
#     626 if cmd.rstrip().endswith("&"):
#     627     # this is *far* from a rigorous test
#     628     # We do not support backgrounding processes because we either use
#     629     # pexpect or pipes to read from.  Users can always just call
#     630     # os.system() or use ip.system=ip.system_raw
#     631     # if they really want a background process.
# ...

# %%
from dask.distributed import Client
client = Client()
# Out:
# <Client: 'tcp://127.0.0.1:38407' processes=4 threads=8, memory=15.36 GiB>

# %%
from utils import ProgressParallel, download_file

navec_path = download_file('hudlit_12B_500K_300d_100q.tar',
        "https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar")

lenta_path = download_file("lenta-ru-news.csv.gz",
    "https://github.com/yutkin/Lenta.Ru-News-Dataset/releases/download/v1.1/lenta-ru-news.csv.bz2")
nerus_file = download_file("nerus_lenta.conllu.gz", "https://storage.yandexcloud.net/natasha-nerus/data/nerus_lenta.conllu.gz")
# Out:
# donwloading lenta-ru-news.csv.gz to ./cache/lenta-ru-news.csv.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       1 from utils import ProgressParallel, download_file
#       3 navec_path = download_file('hudlit_12B_500K_300d_100q.tar',
#       4         "https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar")
# ----> 6 lenta_path = download_file("lenta-ru-news.csv.gz",
#       7     "https://github.com/yutkin/Lenta.Ru-News-Dataset/releases/download/v1.1/lenta-ru-news.csv.bz2")
#       8 nerus_file = download_file("nerus_lenta.conllu.gz", "https://storage.yandexcloud.net/natasha-nerus/data/nerus_lenta.conllu.gz")
#
# File ~/projects/audio-ml/utils.py:38, in download_file(file, url)
#      36 print("donwloading", file, "to", file_path)
#      37 # url = BASE_URL + file
# ...

# %%
from dask.distributed import Client
import dask.array as da
import pymorphy2

client = Client(cluster)

array = da.ones((1000, 1000, 1000))

def process_chunk(chunk):
    # print(chunk)
    import pymorphy2

    return chunk * 10


array.rechunk('1000MB').map_blocks(process_chunk, dtype='float64').mean().compute()
# print(array.mean().compute())
# Out:
# /home/misha-sh/.local/lib/python3.8/site-packages/distributed/client.py:1381: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------------+----------------+----------------+
# | Package | Client         | Scheduler      | Workers        |
# +---------+----------------+----------------+----------------+
# | lz4     | None           | 4.3.2          | 4.3.2          |
# | pandas  | None           | 2.0.0          | 2.0.0          |
# | python  | 3.8.10.final.0 | 3.8.16.final.0 | 3.8.16.final.0 |
# +---------+----------------+----------------+----------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# 10.0

# %%
from time import sleep

def inc(x):
    sleep(1)  # simulate actual work
    return str(x+1) + "kek"

from streamz import Stream

source = Stream()
source.scatter().map(inc).buffer(5).gather().sink(print)

for i in range(100):
    source.emit(i)
# Out:
# 1kek
# 2kek
# 3kek
# 4kek
# 5kek
# 6kek
# 7kek
# 8kek
# 9kek
# 10kek
# 11kek
# 12kek
# 13kek
# 14kek
# 15kek
# 16kek
# 17kek
# 18kek
# 19kek
# 20kek
# 21kek
# 22kek
# 23kek
# 24kek
# 25kek
# 26kek
# 27kek
# 28kek
# 29kek
# 30kek
# 31kek
# 32kek
# 33kek
# 34kek
# 35kek
# 36kek
# 37kek
# 38kek
# 39kek
# 40kek
# 41kek
# 42kek
# 43kek
# 44kek
# 45kek
# 46kek
# 47kek
# 48kek
# 49kek
# 50kek
# 51kek
# 52kek
# 53kek
# 54kek
# 55kek
# 56kek
# 57kek
# 58kek
# 59kek
# 60kek
# 61kek
# 62kek
# 63kek
# 64kek
# 65kek
# 66kek
# 67kek
# 68kek
# 69kek
# 70kek
# 71kek
# 72kek
# 73kek
# 74kek
# 75kek
# 76kek
# 77kek
# 78kek
# 79kek
# 80kek
# 81kek
# 82kek
# 83kek
# 84kek
# 85kek
# 86kek
# 87kek
# 88kek
# 89kek
# 90kek
# 91kek
# 92kek
# 93kek
# 94kek
# 95kek
# 96kek
# 97kek
# 98kek
# 99kek
# 100kek

# %%
array.dtype
# Out:
# dtype('float64')

# %%
import data_loader
